# %%
# %matplotlib notebook
import mne
import matplotlib.pyplot as plt


# Load EEG data from EDF file
raw = mne.io.read_raw_edf(r'..\EEG\dataset\S001\S001R04.edf', preload=True)
new_names = {
    'Fc5.': 'FC5', 'Fc3.': 'FC3', 'Fc1.': 'FC1', 'Fcz.': 'FCz', 'Fc2.': 'FC2', 'Fc4.': 'FC4', 'Fc6.': 'FC6',
    'C5..': 'C5', 'C3..': 'C3', 'C1..': 'C1', 'Cz..': 'Cz', 'C2..': 'C2', 'C4..': 'C4', 'C6..': 'C6',
    'Cp5.': 'CP5', 'Cp3.': 'CP3', 'Cp1.': 'CP1', 'Cpz.': 'CPz', 'Cp2.': 'CP2', 'Cp4.': 'CP4', 'Cp6.': 'CP6',
    'Fp1.': 'Fp1', 'Fpz.': 'Fpz', 'Fp2.': 'Fp2',
    'Af7.': 'AF7', 'Af3.': 'AF3', 'Afz.': 'AFz', 'Af4.': 'AF4', 'Af8.': 'AF8',
    'F7..': 'F7', 'F5..': 'F5', 'F3..': 'F3', 'F1..': 'F1', 'Fz..': 'Fz', 'F2..': 'F2', 'F4..': 'F4', 'F6..': 'F6', 'F8..': 'F8',
    'Ft7.': 'FT7', 'Ft8.': 'FT8',
    'T7..': 'T7', 'T8..': 'T8', 'T9..': 'T9', 'T10.': 'T10',
    'Tp7.': 'TP7', 'Tp8.': 'TP8',
    'P7..': 'P7', 'P5..': 'P5', 'P3..': 'P3', 'P1..': 'P1', 'Pz..': 'Pz', 'P2..': 'P2', 'P4..': 'P4', 'P6..': 'P6', 'P8..': 'P8',
    'Po7.': 'PO7', 'Po3.': 'PO3', 'Poz.': 'POz', 'Po4.': 'PO4', 'Po8.': 'PO8',
    'O1..': 'O1', 'Oz..': 'Oz', 'O2..': 'O2', 
    'Iz..': 'Iz'
}

raw.rename_channels(new_names)
raw.set_montage('standard_1005')

raw.filter(1,10)
raw.plot()
# Out:
# Extracting EDF parameters from C:\Users\sanji\Desktop\EEG\dataset\S001\S001R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 2.50 Hz (-6 dB cutoff frequency: 11.25 Hz)
# - Filter length: 529 samples (3.306 s)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# ...

# %%
ica = mne.preprocessing.ICA(n_components=20, random_state=97, max_iter=800)

ica.fit(raw.copy().filter(8, 35))
ica.plot_components()
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 35 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 35.00 Hz
# - Upper transition bandwidth: 8.75 Hz (-6 dB cutoff frequency: 39.38 Hz)
# - Filter length: 265 samples (1.656 s)
#
# Fitting ICA to data using 64 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# ...

# %%
import numpy as np

# Calculate variance of each channel
channel_variances = np.var(raw.get_data(), axis=1)

# Calculate z-scores of these variances
z_scores = (channel_variances - np.mean(channel_variances)) / np.std(channel_variances)

# Consider channels with z-scores beyond an absolute value of 3 as bad
bad_channel_indices = np.where(np.abs(z_scores) > 3)[0]
bad_channel_names = [raw.ch_names[i] for i in bad_channel_indices]

print("Bad Channels:", bad_channel_names)

# Marking identified bad channels in the Raw object
raw.info['bads'] += bad_channel_names
# Out:
# Bad Channels: ['Fp1']

# %%
bad_idx, scores = ica.finds
